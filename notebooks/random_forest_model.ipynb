# %%
#Import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#Load the DatFrame
df = pd.read_csv("/Users/eselasieakpablie/Documents/Python/Stock Predictor/data/processed/TSLA_features.csv")
df.head()
# Out:
#          Date       Open       High        Low      Close     Volume  \
# 0  2020-01-31  42.666668  43.533333  42.167999  43.371334  235789500
# 1  2020-02-03  44.912666  52.409332  44.901333  52.000000  705975000
# 2  2020-02-04  58.863998  64.599335  55.591999  59.137333  914082000
# 3  2020-02-05  54.883999  56.398666  46.940666  48.980000  726357000
# 4  2020-02-06  46.661331  53.055332  45.799999  49.930668  598212000
#
#    return_1d  return_3d  return_7d  return_2d  ...      CCI_20  upper_shadow  \
# 0   0.015231   0.147592   0.142233   0.119761  ...  167.194021      0.161999
# 1   0.198949   0.342536   0.363160   0.217209  ...  257.319634      0.409332
# 2   0.137256   0.384279   0.570518   0.363512  ...  328.258303      5.462002
# 3  -0.171758   0.129317   0.316620  -0.058077  ...  154.411882      1.514668
# 4   0.019409  -0.039795   0.321150  -0.155683  ...  115.416896      3.124664
#
#    lower_shadow  is_bull  big_move  Monday  Tuesday  Wednesday  Thursday  \
# ...

# %%
#Feature Selection
target = "return_1d"
features = df.columns.drop(["Date", "return_1d"])
X = df[features]
y = df[target]

split_index = int(len(df) * 0.8)

X_train, X_test = X.iloc[:split_index], X.iloc[split_index:]
y_train, y_test = y.iloc[:split_index], y.iloc[split_index:]

# %%
#Random Forest Model
model = RandomForestRegressor(
    n_estimators=300,
    max_depth=10,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=300, random_state=42)

# %%
#Model Evaluation
preds = model.predict(X_test)

mae = mean_absolute_error(y_test, preds)
rmse = np.sqrt(mean_squared_error(y_test, preds))
r2 = r2_score(y_test, preds)

mae, rmse, r2
# Out:
# (0.015809572014659885, np.float64(0.022194848414595115), 0.7337588293045318)

# %%
import sys
print(sys.executable)
   # Should show: /Users/eselasieakpablie/Documents/Python/Stock Predictor/venv/bin/python
# Out:
# /Users/eselasieakpablie/Documents/Python/Stock Predictor/venv/bin/python
